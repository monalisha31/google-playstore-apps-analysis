# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# In this assignment , I am going to analyse the "Google Playstore Apps dataset".Before analyzing the data, First let's  get to know the dataset

# %% [markdown]
# # READING THE DATASET

# %%
#READING DATA
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
#SIZE OF THE DATASET
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.shape
# Out:
# (10841, 13)

# %%
#DISPLAYING THE FIRST FIVE ELEMENTS OF DATA
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#INFORMATION ABOUT THE DATASET
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#COLUMNS OF THE DATASET
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# # DATA   ANALYSIS

# %%
#FINDING THE TOTAL CATEGORY OF APPS
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
#SORTING THE DATA BY RATINGS
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.sort_values(by='Rating', ascending=False).head()
# Out:
#                                            App  Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame       1.9    19.0    3.0M
# 9511                  Ek Bander Ne Kholi Dukan    FAMILY     5.0      10
# 10166                     FA Player Essentials    SPORTS     5.0       7
# 7895                Dine In CT - Food Delivery  SHOPPING     5.0       4
# 5118                          Eternal Light AG    SOCIAL     5.0      30
#
#          Size Installs  Type     Price Content Rating             Genres  \
# 10472  1,000+     Free     0  Everyone            NaN  February 11, 2018
# 9511     3.0M  10,000+  Free         0       Everyone      Entertainment
# 10166     68M     100+  Free         0       Everyone             Sports
# 7895     1.6M   1,000+  Free         0       Everyone           Shopping
# 5118      13M     100+  Free         0           Teen             Social
#
#         Last Updated Current Ver   Android Ver
# ...

# %%
#MOST INSTALLED APPS 
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds['Installs'] = ds.Installs.str.replace(",","")
ds['Installs'] = ds.Installs.str.replace("+","")
ds['Installs'] = ds.Installs.replace("Free",np.nan)
ds['Installs'] = ds['Installs'].astype(float)
ds.drop_duplicates(inplace=True)
ds[ds['Installs'] == 1000000000.0]
# Out:
#                                            App             Category  Rating  \
# 152                          Google Play Books  BOOKS_AND_REFERENCE     3.9
# 335   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 336                         WhatsApp Messenger        COMMUNICATION     4.4
# 338               Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                      Gmail        COMMUNICATION     4.3
# 341                                   Hangouts        COMMUNICATION     4.0
# 382   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 386                                   Hangouts        COMMUNICATION     4.0
# 391              Skype - free IM & video calls        COMMUNICATION     4.1
# 411               Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 451                                      Gmail        COMMUNICATION     4.3
# ...

# %%
#DROPPING DUPLICATE VALUES
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.drop_duplicates(inplace=True)
ds.shape
# Out:
# (10358, 13)

# %%
#DISPLAYING ALL THE CATEGORIES AND THEIR COUNTS
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.drop_duplicates(inplace=True)
ds.Category.value_counts()
# Out:
# FAMILY                 1943
# GAME                   1121
# TOOLS                   844
# BUSINESS                427
# MEDICAL                 408
# PRODUCTIVITY            407
# PERSONALIZATION         388
# LIFESTYLE               373
# COMMUNICATION           366
# FINANCE                 360
# SPORTS                  351
# PHOTOGRAPHY             322
# HEALTH_AND_FITNESS      306
# SOCIAL                  280
# NEWS_AND_MAGAZINES      264
# TRAVEL_AND_LOCAL        237
# BOOKS_AND_REFERENCE     230
# SHOPPING                224
# DATING                  196
# VIDEO_PLAYERS           175
# MAPS_AND_NAVIGATION     137
# EDUCATION               130
# FOOD_AND_DRINK          124
# ENTERTAINMENT           111
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# HOUSE_AND_HOME           80
# ART_AND_DESIGN           65
# EVENTS                   64
# COMICS                   60
# PARENTING                60
# BEAUTY                   53
# ...

# %%
#APPS WITH MOST REVIEWS
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.drop_duplicates(inplace=True)
ds[ds.Reviews>40000000]
# Out:
#                                            App       Category  Rating  \
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 336                         WhatsApp Messenger  COMMUNICATION     4.4
# 382   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 1670                            Clash of Clans           GAME     4.6
# 1879                            Clash of Clans           GAME     4.6
# 2544                                  Facebook         SOCIAL     4.1
# 2545                                 Instagram         SOCIAL     4.5
# 2604                                 Instagram         SOCIAL     4.5
# 3904                        WhatsApp Messenger  COMMUNICATION     4.4
# 3909                                 Instagram         SOCIAL     4.5
# 3943                                  Facebook         SOCIAL     4.1
# 3986                            Clash of Clans         FAMILY     4.6
# ...

# %%
#MOST EXPENSIVE APP
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.drop_duplicates(inplace=True)
newPrice = []

for row in ds.Price:
    if row!= "0":
        newrow = float(row[1:])
    else:
        newrow = 0 
        
    newPrice.append(newrow)
        
ds.Price = newPrice
ds[ds.Price == ds.Price.max()]
# Out:
#                            App   Category  Rating  Reviews  Size Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6      275  7.3M  10,000+
#
#       Type  Price Content Rating     Genres Last Updated Current Ver  \
# 4367  Paid  400.0       Everyone  Lifestyle     3-May-18       1.0.1
#
#      Android Ver
# 4367  4.1 and up

# %%
#CATEGORY GRAPH
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.drop_duplicates(inplace=True)
ds.Category.value_counts().plot(kind='barh',figsize= (12,8))
plt.show()

# %%
#APPS WITH FULL RATINGS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.drop_duplicates(inplace=True)

print("No. of Apps with full ratings: ",ds.Rating[ds['Rating'] == 5 ].count())
# Out:
# No. of Apps with full ratings:  271

# %%
#PRICE DISTRIBUTION PIE CHART
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")


newPrice = []

for row in ds.Price:
    if row!= "0":
        newrow = float(row[1:])
    else:
        newrow = 0 
        
    newPrice.append(newrow)
        
ds.Price = newPrice

plt.pie(ds.Type.value_counts(), labels=['Free', 'Paid'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5267ee0550>,
# ...
#  [Text(-1.070566794830964, 0.2527582596184673, 'Free'),
#   Text(1.0705667889147297, -0.2527582846768919, 'Paid')],
#  [Text(-0.5839455244532531, 0.13786814161007305, '92.6%'),
#   Text(0.5839455212262161, -0.13786815527830465, '7.4%')])

# %%
#RATING GRAPH
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.dropna(inplace=True)
sns.distplot(ds.Rating)

# %%
#REVIEWS DISTRIBUTION GRAPH
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.dropna(inplace=True)
plt.figure(figsize=(10,5))
sns.distplot(ds.Reviews)

# %%
#ANDROID USERS DISTRIBUTION GRAPH
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.dropna(inplace=True)
newVer = []

for row in ds['Android Ver']:
    try:
        newrow = float(row[:2])
    except:
        newrow = 0  
    
    newVer.append(newrow)
    
ds['Android Ver'] =  newVer
sns.countplot(ds['Android Ver'])

# %%
#CONTENT RATING
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 


data = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
plt.figure(figsize=(10,7))
sns.countplot(data=data, x='Content Rating')
plt.xticks(rotation=80)
plt.title('Content Rating',color = 'blue',fontsize=15)
plt.show()

# %%
#MOST POPULAR APPS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.drop_duplicates(inplace=True)
ds_full = ds[ds.Rating == 5]
ds_full.head()
# Out:
#                                             App Category  Rating  Reviews  \
# 329                Hojiboy Tojiboyev Life Hacks   COMICS     5.0       15
# 612               American Girls Mobile Numbers   DATING     5.0        5
# 615                                Awake Dating   DATING     5.0        2
# 633                       Spine- The dating app   DATING     5.0        5
# 636  Girls Live Talk - Free Text and Video Chat   DATING     5.0        6
#
#      Size Installs  Type Price Content Rating  Genres Last Updated  \
# 329   37M   1,000+  Free     0       Everyone  Comics    26-Jun-18
# 612  4.4M   1,000+  Free     0     Mature 17+  Dating    17-Jul-18
# 615   70M     100+  Free     0     Mature 17+  Dating    24-Jul-18
# 633  9.3M     500+  Free     0           Teen  Dating    14-Jul-18
# 636  5.0M     100+  Free     0     Mature 17+  Dating     1-Aug-18
#
#     Current Ver   Android Ver
# 329           2  4.0.3 and up
# 612           3  4.0.3 and up
# ...

# %%
# Apps that have full ratings but less downloads/installs
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.drop_duplicates(inplace=True)
ds_full = ds[ds.Rating == 5]
ds_full.Installs.value_counts().sort_index()
# Out:
# 1+           3
# 1,000+      37
# 10+         48
# 10,000+      1
# 100+       112
# 5+           8
# 5,000+       3
# 50+         32
# 500+        27
# Name: Installs, dtype: int64

# %% [markdown]
# # RESULTS

# %% [raw]
# In this Notebook, I have analysed the dataset (taken from Kaggle) of all the Apps in the Google Play Store.At last ,I have arrived at the following conclusion

# %%
1.We have got 8886 apps to analyze for their ratings and performance.
2.Most of the apps, clearly hold a rating above 4.0 according to the graph And surprisingly a lot seem to have 5.0 rating.
3.There are 271 Apps in the store which hold 5.0 Ratings.
4.The most famous Apps like WhatsApp, Facebook and Clash of Clans are the most reviewed Apps.
5.92.6% of the Apps are Free in the Play Store.
6.The most costly App in the Store is: I'm Rich - Trump Edition costing 400 Dollars.
7.Most of the apps support Android 4.0 and above.
8.Most of the are for every  age group according to the content rating graph.
9. Apps related to Education, LifeStyle and Tools seem to fetch full Ratings with sufficient number of reviews.
10.All the Apps with 5.0 ratings are Free to install.
